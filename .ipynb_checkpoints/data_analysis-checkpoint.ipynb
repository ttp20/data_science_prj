# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### Import necessary modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('clean_data.csv')

# %% [markdown]
# ### Clean data

# %%
df.head()
# Out:
#                       name         dob  math  physics  chemistry  english  \
# 0      phạm hoàng hương ái  04/11/2002   6.6    -1.00      -1.00      5.2
# 1       đặng huỳnh vĩnh an  13/12/2002   8.2    -1.00      -1.00      7.0
# 2  lâm nguyễn mộng thùy an  06/04/2001   6.8    -1.00      -1.00      6.0
# 3         lê tiêu hoàng an  18/11/2002   7.8     5.50       6.25      5.6
# 4              lư thuận an  14/01/2002   6.4     6.75       6.25      8.2
#
#    biology  literature  history  geography  civic education  natural science  \
# 0     -1.0        6.25     5.75       7.00             7.25            -1.00
# 1     -1.0        7.75     7.00       7.25             8.50            -1.00
# 2     -1.0        6.75     4.75       7.75             8.25            -1.00
# 3      7.0        6.25    -1.00      -1.00            -1.00             6.25
# 4      5.5        6.50    -1.00      -1.00            -1.00             6.17
#
#    social science  Unnamed: 13
# 0            6.67          NaN
# 1            7.58          NaN
# 2            6.92          NaN
# 3           -1.00          NaN
# 4           -1.00          NaN

# %% [markdown]
# ### Drop the last column

# %%
df.drop(df.columns[[-1]], axis=1, inplace=True)

# %%
df.head()
# Out:
#                       name         dob  math  physics  chemistry  english  \
# 0      phạm hoàng hương ái  04/11/2002   6.6    -1.00      -1.00      5.2
# 1       đặng huỳnh vĩnh an  13/12/2002   8.2    -1.00      -1.00      7.0
# 2  lâm nguyễn mộng thùy an  06/04/2001   6.8    -1.00      -1.00      6.0
# 3         lê tiêu hoàng an  18/11/2002   7.8     5.50       6.25      5.6
# 4              lư thuận an  14/01/2002   6.4     6.75       6.25      8.2
#
#    biology  literature  history  geography  civic education  natural science  \
# 0     -1.0        6.25     5.75       7.00             7.25            -1.00
# 1     -1.0        7.75     7.00       7.25             8.50            -1.00
# 2     -1.0        6.75     4.75       7.75             8.25            -1.00
# 3      7.0        6.25    -1.00      -1.00            -1.00             6.25
# 4      5.5        6.50    -1.00      -1.00            -1.00             6.17
#
#    social science
# 0            6.67
# 1            7.58
# 2            6.92
# 3           -1.00
# 4           -1.00

# %% [markdown]
# ### Change faulty dates of birth (00/00) to (01/01)

# %%
df['dob'] = df['dob'].apply(lambda x: x.replace('00/00', '01/01'))

# %%
df['dob'] =  pd.to_datetime(df['dob'], format='%d/%m/%Y')

# %%
df.head()
# Out:
#                       name        dob  math  physics  chemistry  english  \
# 0      phạm hoàng hương ái 2002-11-04   6.6    -1.00      -1.00      5.2
# 1       đặng huỳnh vĩnh an 2002-12-13   8.2    -1.00      -1.00      7.0
# 2  lâm nguyễn mộng thùy an 2001-04-06   6.8    -1.00      -1.00      6.0
# 3         lê tiêu hoàng an 2002-11-18   7.8     5.50       6.25      5.6
# 4              lư thuận an 2002-01-14   6.4     6.75       6.25      8.2
#
#    biology  literature  history  geography  civic education  natural science  \
# 0     -1.0        6.25     5.75       7.00             7.25            -1.00
# 1     -1.0        7.75     7.00       7.25             8.50            -1.00
# 2     -1.0        6.75     4.75       7.75             8.25            -1.00
# 3      7.0        6.25    -1.00      -1.00            -1.00             6.25
# 4      5.5        6.50    -1.00      -1.00            -1.00             6.17
#
#    social science
# 0            6.67
# 1            7.58
# 2            6.92
# 3           -1.00
# 4           -1.00

# %% [markdown]
# ### Capitalise name (Note that Vietnamese name has the following format: Family Name - Middle Name(s) - First Name

# %%
df['name'] = df['name'].apply(lambda x: x.title())

# %%
df.head()
# Out:
#                       name        dob  math  physics  chemistry  english  \
# 0      Phạm Hoàng Hương Ái 2002-11-04   6.6    -1.00      -1.00      5.2
# 1       Đặng Huỳnh Vĩnh An 2002-12-13   8.2    -1.00      -1.00      7.0
# 2  Lâm Nguyễn Mộng Thùy An 2001-04-06   6.8    -1.00      -1.00      6.0
# 3         Lê Tiêu Hoàng An 2002-11-18   7.8     5.50       6.25      5.6
# 4              Lư Thuận An 2002-01-14   6.4     6.75       6.25      8.2
#
#    biology  literature  history  geography  civic education  natural science  \
# 0     -1.0        6.25     5.75       7.00             7.25            -1.00
# 1     -1.0        7.75     7.00       7.25             8.50            -1.00
# 2     -1.0        6.75     4.75       7.75             8.25            -1.00
# 3      7.0        6.25    -1.00      -1.00            -1.00             6.25
# 4      5.5        6.50    -1.00      -1.00            -1.00             6.17
#
#    social science
# 0            6.67
# 1            7.58
# 2            6.92
# 3           -1.00
# 4           -1.00

# %% [markdown]
# ### Question 1: Which subject is taken by the most number of students ?

# %%
df.shape
# Out:
# (74171, 13)

# %%
number_of_students = df.shape[0] #74171

number_of_students_not_taking_maths = df[df['math'] == - 1].shape[0]
number_of_students_not_taking_physics = df[df['physics'] == - 1].shape[0]
number_of_students_not_taking_chemistry = df[df['chemistry'] == - 1].shape[0]
number_of_students_not_taking_english = df[df['english'] == - 1].shape[0]
number_of_students_not_taking_biology = df[df['biology'] == - 1].shape[0]
number_of_students_not_taking_literature = df[df['literature'] == - 1].shape[0]
number_of_students_not_taking_history = df[df['history'] == - 1].shape[0]
number_of_students_not_taking_geography = df[df['geography'] == - 1].shape[0]
number_of_students_not_taking_civic_education = df[df['civic education'] == - 1].shape[0]
number_of_students_not_taking_natural_science = df[df['natural science'] == - 1].shape[0]
number_of_students_not_taking_social_science = df[df['social science'] == - 1].shape[0]

# %%
df.columns
# Out:
# Index(['name', 'dob', 'math', 'physics', 'chemistry', 'english', 'biology',
#        'literature', 'history', 'geography', 'civic education',
#        'natural science', 'social science'],
#       dtype='object')

# %%
subject_lists = df.columns[2:]
subject_lists
# Out:
# Index(['math', 'physics', 'chemistry', 'english', 'biology', 'literature',
#        'history', 'geography', 'civic education', 'natural science',
#        'social science'],
#       dtype='object')

# %%
not_taking_students = [df[df[i] == - 1].shape[0] for i in subject_lists]
not_taking_students
# Out:
# [250, 31428, 31143, 8637, 31675, 1803, 44021, 44737, 49097, 32329, 49114]

# %%
fig, ax = plt.subplots(figsize=(12,9))
plt.bar(subject_lists, not_taking_students)
plt.xticks(rotation=45)
plt.title("Number of students not taking each of these subjects")
plt.xlabel("Subjects")
plt.ylabel("Number of students")
plt.show()

# %%
taking_students = [number_of_students - i for i in not_taking_students]

# %%
fig, ax = plt.subplots(figsize=(12,9))
plt.bar(subject_lists, taking_students, color='red')
plt.xticks(rotation=45)
plt.title("Number of students taking each of these subjects")
plt.xlabel("Subjects")
plt.ylabel("Number of students")
plt.show()

# %% [markdown]
# ### How many subjects are taken by what percentage of students ?

# %%
df.head()
# Out:
#                       name        dob  math  physics  chemistry  english  \
# 0      Phạm Hoàng Hương Ái 2002-11-04   6.6    -1.00      -1.00      5.2
# 1       Đặng Huỳnh Vĩnh An 2002-12-13   8.2    -1.00      -1.00      7.0
# 2  Lâm Nguyễn Mộng Thùy An 2001-04-06   6.8    -1.00      -1.00      6.0
# 3         Lê Tiêu Hoàng An 2002-11-18   7.8     5.50       6.25      5.6
# 4              Lư Thuận An 2002-01-14   6.4     6.75       6.25      8.2
#
#    biology  literature  history  geography  civic education  natural science  \
# 0     -1.0        6.25     5.75       7.00             7.25            -1.00
# 1     -1.0        7.75     7.00       7.25             8.50            -1.00
# 2     -1.0        6.75     4.75       7.75             8.25            -1.00
# 3      7.0        6.25    -1.00      -1.00            -1.00             6.25
# 4      5.5        6.50    -1.00      -1.00            -1.00             6.17
#
#    social science
# 0            6.67
# 1            7.58
# 2            6.92
# 3           -1.00
# 4           -1.00

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#                           name        dob  math  physics  chemistry  english  \
# 0          Phạm Hoàng Hương Ái 2002-11-04   6.6    -1.00      -1.00      5.2
# 1           Đặng Huỳnh Vĩnh An 2002-12-13   8.2    -1.00      -1.00      7.0
# 2      Lâm Nguyễn Mộng Thùy An 2001-04-06   6.8    -1.00      -1.00      6.0
# 3             Lê Tiêu Hoàng An 2002-11-18   7.8     5.50       6.25      5.6
# 4                  Lư Thuận An 2002-01-14   6.4     6.75       6.25      8.2
# ...                        ...        ...   ...      ...        ...      ...
# 74166      Nguyễn Đình Hải Yến 2002-11-10   5.4     3.50       5.00     -1.0
# 74167       Nguyễn Thị Hải Yến 2002-05-05   8.6     8.25       8.75      6.2
# 74168     Nguyễn Trần Tiểu Yến 2002-10-07   9.2     8.75       8.50      6.2
# 74169         Phạm Thị Kim Yến 2002-11-20   9.0     8.00       9.25      7.0
# 74170             Văn Hồng Yến 2002-10-27   5.6    -1.00      -1.00     -1.0
#
#        biology  literature  history  geography  civic education  \
# 0        -1.00        6.25     5.75       7.00             7.25
# 1        -1.00        7.75     7.00       7.25             8.50
# 2        -1.00        6.75     4.75       7.75             8.25
# 3         7.00        6.25    -1.00      -1.00            -1.00
# 4         5.50        6.50    -1.00      -1.00            -1.00
# ...        ...         ...      ...        ...              ...
# 74166     5.50        5.92    -1.00      -1.00            -1.00
# 74167     6.75        7.00    -1.00      -1.00            -1.00
# 74168     8.25        7.50    -1.00      -1.00            -1.00
# 74169     6.75        7.00    -1.00      -1.00            -1.00
# 74170    -1.00        6.50     6.50       7.25            -1.00
#
#        natural science  social science
# 0                -1.00            6.67
# 1                -1.00            7.58
# 2                -1.00            6.92
# 3                 6.25           -1.00
# 4                 6.17           -1.00
# ...                ...             ...
# 74166             4.67           -1.00
# 74167             7.92           -1.00
# 74168             8.50           -1.00
# 74169             8.00           -1.00
# 74170            -1.00           -1.00
#
# [74171 rows x 13 columns]

# %%
df1 = pd.DataFrame(columns=df.columns)
df1[['name', 'dob']] = df[['name', 'dob']]

# %%
def count(x):
    if x == -1:
        return 0
    else:
        return 1

# %%
for subject in subject_lists:
    df1[subject] = df[subject].apply(lambda x: count(x))

# %%
df1
# Out:
#                           name        dob  math  physics  chemistry  english  \
# 0          Phạm Hoàng Hương Ái 2002-11-04     1        0          0        1
# 1           Đặng Huỳnh Vĩnh An 2002-12-13     1        0          0        1
# 2      Lâm Nguyễn Mộng Thùy An 2001-04-06     1        0          0        1
# 3             Lê Tiêu Hoàng An 2002-11-18     1        1          1        1
# 4                  Lư Thuận An 2002-01-14     1        1          1        1
# ...                        ...        ...   ...      ...        ...      ...
# 74166      Nguyễn Đình Hải Yến 2002-11-10     1        1          1        0
# 74167       Nguyễn Thị Hải Yến 2002-05-05     1        1          1        1
# 74168     Nguyễn Trần Tiểu Yến 2002-10-07     1        1          1        1
# 74169         Phạm Thị Kim Yến 2002-11-20     1        1          1        1
# 74170             Văn Hồng Yến 2002-10-27     1        0          0        0
#
#        biology  literature  history  geography  civic education  \
# 0            0           1        1          1                1
# 1            0           1        1          1                1
# 2            0           1        1          1                1
# 3            1           1        0          0                0
# 4            1           1        0          0                0
# ...        ...         ...      ...        ...              ...
# 74166        1           1        0          0                0
# 74167        1           1        0          0                0
# 74168        1           1        0          0                0
# 74169        1           1        0          0                0
# 74170        0           1        1          1                0
#
#        natural science  social science
# 0                    0               1
# 1                    0               1
# 2                    0               1
# 3                    1               0
# 4                    1               0
# ...                ...             ...
# 74166                1               0
# 74167                1               0
# 74168                1               0
# 74169                1               0
# 74170                0               0
#
# [74171 rows x 13 columns]

# %%
df1["no of subjects"] = df1.iloc[:,2:].sum(axis=1)
df1
# Out:
#                           name        dob  math  physics  chemistry  english  \
# 0          Phạm Hoàng Hương Ái 2002-11-04     1        0          0        1
# 1           Đặng Huỳnh Vĩnh An 2002-12-13     1        0          0        1
# 2      Lâm Nguyễn Mộng Thùy An 2001-04-06     1        0          0        1
# 3             Lê Tiêu Hoàng An 2002-11-18     1        1          1        1
# 4                  Lư Thuận An 2002-01-14     1        1          1        1
# ...                        ...        ...   ...      ...        ...      ...
# 74166      Nguyễn Đình Hải Yến 2002-11-10     1        1          1        0
# 74167       Nguyễn Thị Hải Yến 2002-05-05     1        1          1        1
# 74168     Nguyễn Trần Tiểu Yến 2002-10-07     1        1          1        1
# 74169         Phạm Thị Kim Yến 2002-11-20     1        1          1        1
# 74170             Văn Hồng Yến 2002-10-27     1        0          0        0
#
#        biology  literature  history  geography  civic education  \
# 0            0           1        1          1                1
# 1            0           1        1          1                1
# 2            0           1        1          1                1
# 3            1           1        0          0                0
# 4            1           1        0          0                0
# ...        ...         ...      ...        ...              ...
# 74166        1           1        0          0                0
# 74167        1           1        0          0                0
# 74168        1           1        0          0                0
# 74169        1           1        0          0                0
# 74170        0           1        1          1                0
#
#        natural science  social science  no of subjects
# 0                    0               1               7
# 1                    0               1               7
# 2                    0               1               7
# 3                    1               0               7
# 4                    1               0               7
# ...                ...             ...             ...
# 74166                1               0               6
# 74167                1               0               7
# 74168                1               0               7
# 74169                1               0               7
# 74170                0               0               4
#
# [74171 rows x 14 columns]

# %%
dfg = df1.groupby('no of subjects').size()
dfg
# Out:
# no of subjects
# 1        80
# 2       120
# 3      2602
# 4      4331
# 5       297
# 6      2479
# 7     64261
# 11        1
# dtype: int64

# %%
dfg = pd.DataFrame(dfg, columns=['no_of_students'])
for index in dfg.index:
    print(index)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 11

# %%
number_of_subjects_taken = dfg.index.to_numpy()
corresponding_number_of_students = dfg['no_of_students'].to_numpy()

# %%
fig1, ax1 = plt.subplots(figsize=(12, 9))
ax1.pie(corresponding_number_of_students, counterclock=False)
plt.legend(number_of_subjects_taken, loc='best')
plt.title("Students broken down by their number of exams taken")
plt.show()

# %% [markdown]
# ### Mean scores of each subject (Mean score of math, physics, chemistry,...)

# %%
df
# Out:
#                           name        dob  math  physics  chemistry  english  \
# 0          Phạm Hoàng Hương Ái 2002-11-04   6.6    -1.00      -1.00      5.2
# 1           Đặng Huỳnh Vĩnh An 2002-12-13   8.2    -1.00      -1.00      7.0
# 2      Lâm Nguyễn Mộng Thùy An 2001-04-06   6.8    -1.00      -1.00      6.0
# 3             Lê Tiêu Hoàng An 2002-11-18   7.8     5.50       6.25      5.6
# 4                  Lư Thuận An 2002-01-14   6.4     6.75       6.25      8.2
# ...                        ...        ...   ...      ...        ...      ...
# 74166      Nguyễn Đình Hải Yến 2002-11-10   5.4     3.50       5.00     -1.0
# 74167       Nguyễn Thị Hải Yến 2002-05-05   8.6     8.25       8.75      6.2
# 74168     Nguyễn Trần Tiểu Yến 2002-10-07   9.2     8.75       8.50      6.2
# 74169         Phạm Thị Kim Yến 2002-11-20   9.0     8.00       9.25      7.0
# 74170             Văn Hồng Yến 2002-10-27   5.6    -1.00      -1.00     -1.0
#
#        biology  literature  history  geography  civic education  \
# 0        -1.00        6.25     5.75       7.00             7.25
# 1        -1.00        7.75     7.00       7.25             8.50
# 2        -1.00        6.75     4.75       7.75             8.25
# 3         7.00        6.25    -1.00      -1.00            -1.00
# 4         5.50        6.50    -1.00      -1.00            -1.00
# ...        ...         ...      ...        ...              ...
# 74166     5.50        5.92    -1.00      -1.00            -1.00
# 74167     6.75        7.00    -1.00      -1.00            -1.00
# 74168     8.25        7.50    -1.00      -1.00            -1.00
# 74169     6.75        7.00    -1.00      -1.00            -1.00
# 74170    -1.00        6.50     6.50       7.25            -1.00
#
#        natural science  social science
# 0                -1.00            6.67
# 1                -1.00            7.58
# 2                -1.00            6.92
# 3                 6.25           -1.00
# 4                 6.17           -1.00
# ...                ...             ...
# 74166             4.67           -1.00
# 74167             7.92           -1.00
# 74168             8.50           -1.00
# 74169             8.00           -1.00
# 74170            -1.00           -1.00
#
# [74171 rows x 13 columns]

# %%
for subject in subject_lists:
    df[subject] = df[subject].apply(lambda x: None if (x==-1) else x)

# %%
df
# Out:
#                           name        dob  math  physics  chemistry  english  \
# 0          Phạm Hoàng Hương Ái 2002-11-04   6.6      NaN        NaN      5.2
# 1           Đặng Huỳnh Vĩnh An 2002-12-13   8.2      NaN        NaN      7.0
# 2      Lâm Nguyễn Mộng Thùy An 2001-04-06   6.8      NaN        NaN      6.0
# 3             Lê Tiêu Hoàng An 2002-11-18   7.8     5.50       6.25      5.6
# 4                  Lư Thuận An 2002-01-14   6.4     6.75       6.25      8.2
# ...                        ...        ...   ...      ...        ...      ...
# 74166      Nguyễn Đình Hải Yến 2002-11-10   5.4     3.50       5.00      NaN
# 74167       Nguyễn Thị Hải Yến 2002-05-05   8.6     8.25       8.75      6.2
# 74168     Nguyễn Trần Tiểu Yến 2002-10-07   9.2     8.75       8.50      6.2
# 74169         Phạm Thị Kim Yến 2002-11-20   9.0     8.00       9.25      7.0
# 74170             Văn Hồng Yến 2002-10-27   5.6      NaN        NaN      NaN
#
#        biology  literature  history  geography  civic education  \
# 0          NaN        6.25     5.75       7.00             7.25
# 1          NaN        7.75     7.00       7.25             8.50
# 2          NaN        6.75     4.75       7.75             8.25
# 3         7.00        6.25      NaN        NaN              NaN
# 4         5.50        6.50      NaN        NaN              NaN
# ...        ...         ...      ...        ...              ...
# 74166     5.50        5.92      NaN        NaN              NaN
# 74167     6.75        7.00      NaN        NaN              NaN
# 74168     8.25        7.50      NaN        NaN              NaN
# 74169     6.75        7.00      NaN        NaN              NaN
# 74170      NaN        6.50     6.50       7.25              NaN
#
#        natural science  social science
# 0                  NaN            6.67
# 1                  NaN            7.58
# 2                  NaN            6.92
# 3                 6.25             NaN
# 4                 6.17             NaN
# ...                ...             ...
# 74166             4.67             NaN
# 74167             7.92             NaN
# 74168             8.50             NaN
# 74169             8.00             NaN
# 74170              NaN             NaN
#
# [74171 rows x 13 columns]

# %%
mean_score_by_subjects = []
for subject in subject_lists:
    mean_score_by_subjects.append(df[subject].mean(skipna=True))

# %%
fig, ax = plt.subplots(figsize=(12,9))
bars = plt.bar(subject_lists, mean_score_by_subjects)
plt.title("Mean score by subjects")
plt.xlabel("Subjects")
plt.ylabel("Mean score")
plt.xticks(rotation=45)
# access the bar attributes to place the text in the appropriate location
for bar in bars:
    plt.text(bar.get_x() + .2, bar.get_height() + .05, round(bar.get_height(),2))

# %% [markdown]
# ### Mean scores of students grouped by their number of subjects taken

# %%
df["no of subjects"] = df1['no of subjects']

# %%
df['avg score'] = df.iloc[:,2:13].sum(axis=1, skipna=True) / df['no of subjects']

# %%
df
# Out:
#                           name        dob  math  physics  chemistry  english  \
# 0          Phạm Hoàng Hương Ái 2002-11-04   6.6      NaN        NaN      5.2
# 1           Đặng Huỳnh Vĩnh An 2002-12-13   8.2      NaN        NaN      7.0
# 2      Lâm Nguyễn Mộng Thùy An 2001-04-06   6.8      NaN        NaN      6.0
# 3             Lê Tiêu Hoàng An 2002-11-18   7.8     5.50       6.25      5.6
# 4                  Lư Thuận An 2002-01-14   6.4     6.75       6.25      8.2
# ...                        ...        ...   ...      ...        ...      ...
# 74166      Nguyễn Đình Hải Yến 2002-11-10   5.4     3.50       5.00      NaN
# 74167       Nguyễn Thị Hải Yến 2002-05-05   8.6     8.25       8.75      6.2
# 74168     Nguyễn Trần Tiểu Yến 2002-10-07   9.2     8.75       8.50      6.2
# 74169         Phạm Thị Kim Yến 2002-11-20   9.0     8.00       9.25      7.0
# 74170             Văn Hồng Yến 2002-10-27   5.6      NaN        NaN      NaN
#
#        biology  literature  history  geography  civic education  \
# 0          NaN        6.25     5.75       7.00             7.25
# 1          NaN        7.75     7.00       7.25             8.50
# 2          NaN        6.75     4.75       7.75             8.25
# 3         7.00        6.25      NaN        NaN              NaN
# 4         5.50        6.50      NaN        NaN              NaN
# ...        ...         ...      ...        ...              ...
# 74166     5.50        5.92      NaN        NaN              NaN
# 74167     6.75        7.00      NaN        NaN              NaN
# 74168     8.25        7.50      NaN        NaN              NaN
# 74169     6.75        7.00      NaN        NaN              NaN
# 74170      NaN        6.50     6.50       7.25              NaN
#
#        natural science  social science  no of subjects  avg score
# 0                  NaN            6.67               7   6.388571
# 1                  NaN            7.58               7   7.611429
# 2                  NaN            6.92               7   6.745714
# 3                 6.25             NaN               7   6.378571
# 4                 6.17             NaN               7   6.538571
# ...                ...             ...             ...        ...
# 74166             4.67             NaN               6   4.998333
# 74167             7.92             NaN               7   7.638571
# 74168             8.50             NaN               7   8.128571
# 74169             8.00             NaN               7   7.857143
# 74170              NaN             NaN               4   6.462500
#
# [74171 rows x 15 columns]

# %%
(6.6 + 5.2 + 6.25 + 5.75 + 7 + 7.25 + 6.67)/7
# Out:
# 6.388571428571429

# %%
dfg = df.groupby('no of subjects').mean()['avg score']
dfg
# Out:
# no of subjects
# 1     5.679000
# 2     6.906792
# 3     6.585012
# 4     5.818145
# 5     6.504727
# 6     6.571043
# 7     6.595611
# 11    4.266364
# Name: avg score, dtype: float64

# %%
type(dfg)
# Out:
# pandas.core.series.Series

# %%
dfg.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6, 7, 11], dtype='int64', name='no of subjects')

# %%
mean_scores_by_no_of_subjects = [dfg[i] for i in dfg.index]

# %%
fig, ax = plt.subplots(figsize=(12,9))
bars = plt.bar(dfg.index, mean_scores_by_no_of_subjects)
plt.title("Mean score by number of subjects")
plt.xlabel("Number of subjects")
plt.ylabel("Mean score")
plt.xticks(range(1,12))
# access the bar attributes to place the text in the appropriate location
for bar in bars:
    plt.text(bar.get_x() + .2, bar.get_height() + .05, round(bar.get_height(),2))

# %% [markdown]
# ### Number of students grouped by age

# %%
df
# Out:
#                           name        dob  math  physics  chemistry  english  \
# 0          Phạm Hoàng Hương Ái 2002-11-04   6.6      NaN        NaN      5.2
# 1           Đặng Huỳnh Vĩnh An 2002-12-13   8.2      NaN        NaN      7.0
# 2      Lâm Nguyễn Mộng Thùy An 2001-04-06   6.8      NaN        NaN      6.0
# 3             Lê Tiêu Hoàng An 2002-11-18   7.8     5.50       6.25      5.6
# 4                  Lư Thuận An 2002-01-14   6.4     6.75       6.25      8.2
# ...                        ...        ...   ...      ...        ...      ...
# 74166      Nguyễn Đình Hải Yến 2002-11-10   5.4     3.50       5.00      NaN
# 74167       Nguyễn Thị Hải Yến 2002-05-05   8.6     8.25       8.75      6.2
# 74168     Nguyễn Trần Tiểu Yến 2002-10-07   9.2     8.75       8.50      6.2
# 74169         Phạm Thị Kim Yến 2002-11-20   9.0     8.00       9.25      7.0
# 74170             Văn Hồng Yến 2002-10-27   5.6      NaN        NaN      NaN
#
#        biology  literature  history  geography  civic education  \
# 0          NaN        6.25     5.75       7.00             7.25
# 1          NaN        7.75     7.00       7.25             8.50
# 2          NaN        6.75     4.75       7.75             8.25
# 3         7.00        6.25      NaN        NaN              NaN
# 4         5.50        6.50      NaN        NaN              NaN
# ...        ...         ...      ...        ...              ...
# 74166     5.50        5.92      NaN        NaN              NaN
# 74167     6.75        7.00      NaN        NaN              NaN
# 74168     8.25        7.50      NaN        NaN              NaN
# 74169     6.75        7.00      NaN        NaN              NaN
# 74170      NaN        6.50     6.50       7.25              NaN
#
#        natural science  social science  no of subjects  avg score
# 0                  NaN            6.67               7   6.388571
# 1                  NaN            7.58               7   7.611429
# 2                  NaN            6.92               7   6.745714
# 3                 6.25             NaN               7   6.378571
# 4                 6.17             NaN               7   6.538571
# ...                ...             ...             ...        ...
# 74166             4.67             NaN               6   4.998333
# 74167             7.92             NaN               7   7.638571
# 74168             8.50             NaN               7   8.128571
# 74169             8.00             NaN               7   7.857143
# 74170              NaN             NaN               4   6.462500
#
# [74171 rows x 15 columns]

# %%
df['age'] = df['dob'].apply(lambda x: 2020 - x.year)

# %%
df
# Out:
#                           name        dob  math  physics  chemistry  english  \
# 0          Phạm Hoàng Hương Ái 2002-11-04   6.6      NaN        NaN      5.2
# 1           Đặng Huỳnh Vĩnh An 2002-12-13   8.2      NaN        NaN      7.0
# 2      Lâm Nguyễn Mộng Thùy An 2001-04-06   6.8      NaN        NaN      6.0
# 3             Lê Tiêu Hoàng An 2002-11-18   7.8     5.50       6.25      5.6
# 4                  Lư Thuận An 2002-01-14   6.4     6.75       6.25      8.2
# ...                        ...        ...   ...      ...        ...      ...
# 74166      Nguyễn Đình Hải Yến 2002-11-10   5.4     3.50       5.00      NaN
# 74167       Nguyễn Thị Hải Yến 2002-05-05   8.6     8.25       8.75      6.2
# 74168     Nguyễn Trần Tiểu Yến 2002-10-07   9.2     8.75       8.50      6.2
# 74169         Phạm Thị Kim Yến 2002-11-20   9.0     8.00       9.25      7.0
# 74170             Văn Hồng Yến 2002-10-27   5.6      NaN        NaN      NaN
#
#        biology  literature  history  geography  civic education  \
# 0          NaN        6.25     5.75       7.00             7.25
# 1          NaN        7.75     7.00       7.25             8.50
# 2          NaN        6.75     4.75       7.75             8.25
# 3         7.00        6.25      NaN        NaN              NaN
# 4         5.50        6.50      NaN        NaN              NaN
# ...        ...         ...      ...        ...              ...
# 74166     5.50        5.92      NaN        NaN              NaN
# 74167     6.75        7.00      NaN        NaN              NaN
# 74168     8.25        7.50      NaN        NaN              NaN
# 74169     6.75        7.00      NaN        NaN              NaN
# 74170      NaN        6.50     6.50       7.25              NaN
#
#        natural science  social science  no of subjects  avg score  age
# 0                  NaN            6.67               7   6.388571   18
# 1                  NaN            7.58               7   7.611429   18
# 2                  NaN            6.92               7   6.745714   19
# 3                 6.25             NaN               7   6.378571   18
# 4                 6.17             NaN               7   6.538571   18
# ...                ...             ...             ...        ...  ...
# 74166             4.67             NaN               6   4.998333   18
# 74167             7.92             NaN               7   7.638571   18
# 74168             8.50             NaN               7   8.128571   18
# 74169             8.00             NaN               7   7.857143   18
# 74170              NaN             NaN               4   6.462500   18
#
# [74171 rows x 16 columns]

# %%
count_26_older = 0
for age in df['age']:
    if age > 26:
        count_26_older += 1
count_26_older
# Out:
# 296

# %%
dfg = df.groupby('age').mean()['avg score']
dfg
# Out:
# age
# 17    7.953571
# 18    6.587884
# 19    6.319129
# 20    6.276502
# 21    6.026032
# 22    5.987638
# 23    5.945985
# 24    5.798368
# 25    6.069724
# 26    5.911239
# 27    6.190845
# 28    6.598553
# 29    6.480566
# 30    6.318075
# 31    6.428159
# 32    6.503804
# 33    5.858712
# 34    5.580417
# 35    6.694167
# 36    6.285000
# 37    5.682813
# 38    5.254167
# 39    4.808889
# 40    5.150000
# 41    4.793750
# 42    4.629167
# 43    6.612500
# 44    6.783333
# 45    6.312500
# 46    5.160500
# 47    2.975000
# 48    2.450000
# 49    3.700000
# 51    3.850000
# 55    7.266667
# 56    5.560000
# 57    6.250000
# Name: avg score, dtype: float64

# %%
dfg.index[0:10]
dfg_dict = {}
for age in dfg.index[0:10]:
    dfg_dict[age] = dfg[age]
dfg_dict
# Out:
# {17: 7.953571428571427,
#  18: 6.587883588233329,
#  19: 6.31912913939783,
#  20: 6.276502392916972,
#  21: 6.026032408269695,
#  22: 5.987638008205893,
#  23: 5.9459850294632925,
#  24: 5.798367926542815,
#  25: 6.069723567393057,
#  26: 5.911239405854082}

# %%
dfg_dict['>26'] = count_26_older

# %%
dfg_dict
# Out:
# {17: 7.953571428571427,
#  18: 6.587883588233329,
#  19: 6.31912913939783,
#  20: 6.276502392916972,
#  21: 6.026032408269695,
#  22: 5.987638008205893,
#  23: 5.9459850294632925,
#  24: 5.798367926542815,
#  25: 6.069723567393057,
#  26: 5.911239405854082,
#  '>26': 296}

# %%
dfg = df.groupby('age').size()
dfg
# Out:
# age
# 17        2
# 18    66067
# 19     4455
# 20     1393
# 21      767
# 22      383
# 23      299
# 24      223
# 25      177
# 26      109
# 27       59
# 28       49
# 29       41
# 30       29
# 31       12
# 32       23
# 33       11
# 34       10
# 35        7
# 36        9
# 37        8
# 38        3
# 39        6
# 40        4
# 41        2
# 42        8
# 43        1
# 44        2
# 45        1
# 46        3
# 47        1
# 48        1
# 49        1
# 51        1
# 55        1
# 56        2
# 57        1
# dtype: int64

# %% [markdown]
# ### What is the most popular last name ?

# %%
lastnames = [name.split(" ")[0] for name in df['name']]
lastnames
# Out:
# ['Phạm',
#  'Đặng',
#  'Lâm',
#  'Lê',
#  'Lư',
#  'Mai',
#  'Mai',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Tý',
#  'Võ',
#  'Vũ',
#  'Bùi',
#  'Bùi',
#  'Bùi',
#  'Cao',
#  'Châu',
#  'Chung',
#  'Dương',
#  'Đào',
#  'Đặng',
#  'Hà',
#  'Hà',
#  'Hoàng',
#  'Hồ',
#  'Hồ',
#  'Huỳnh',
#  'Huỳnh',
#  'Lã',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Ngô',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phạm',
#  'Phạm',
#  'Phạm',
#  'Phạm',
#  'Phạm',
#  'Phạm',
#  'Tiến',
#  'Tô',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Hà',
#  'Huỳnh',
#  'Nguyễn',
#  'Hàng',
#  'Hoàng',
#  'Nguyễn',
#  'Phạm',
#  'Dương',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Chung',
#  'Đặng',
#  'Huỳnh',
#  'Lưu',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Phan',
#  'Thái',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Mạnh',
#  'Doãn',
#  'Hồ',
#  'Mai',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Trần',
#  'Trần',
#  'Lâm',
#  'Lê',
#  'Lương',
#  'Lưu',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Trần',
#  'Võ',
#  'Yin',
#  'Bùi',
#  'Chu',
#  'Lê',
#  'Trần',
#  'Trịnh',
#  'Hà',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Bùi',
#  'Du',
#  'Hà',
#  'Lê',
#  'Mai',
#  'Nguyễn',
#  'Vũ',
#  'Mai',
#  'Nguyễn',
#  'Đinh',
#  'Nguyễn',
#  'Nguyễn',
#  'Trần',
#  'Trần',
#  'Vũ',
#  'Nguyễn',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Ngô',
#  'Bùi',
#  'Đào',
#  'Lê',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phạm',
#  'Phan',
#  'Phan',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trịnh',
#  'Đỗ',
#  'Huỳnh',
#  'Lê',
#  'Lư',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Trương',
#  'Nguyễn',
#  'Lê',
#  'Ngô',
#  'Nguyễn',
#  'Đinh',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Trần',
#  'Lê',
#  'Bùi',
#  'Bùi',
#  'Châu',
#  'Dương',
#  'Huỳnh',
#  'Lê',
#  'Lương',
#  'Mai',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Thái',
#  'Trương',
#  'Vũ',
#  'Lê',
#  'Lữ',
#  'Nguyễn',
#  'Ninh',
#  'Phạm',
#  'Trịnh',
#  'Lê',
#  'Nguyễn',
#  'Trần',
#  'Hồng',
#  'Lê',
#  'Vũ',
#  'Bùi',
#  'Dương',
#  'Đinh',
#  'Lê',
#  'Mã',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Tạ',
#  'Trần',
#  'Trịnh',
#  'Trịnh',
#  'Du',
#  'Lương',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Trần',
#  'Võ',
#  'Phạm',
#  'Trần',
#  'Võ',
#  'Đào',
#  'Huỳnh',
#  'Lâm',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Nguyễn',
#  'Phan',
#  'Trần',
#  'Vũ',
#  'Vũ',
#  'Vương',
#  'Kiều',
#  'Lâm',
#  'Lý',
#  'Nguyễn',
#  'Thái',
#  'Lâm',
#  'Lê',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Trần',
#  'Hoàng',
#  'Hồ',
#  'Huỳnh',
#  'Kim',
#  'Lâm',
#  'Lâm',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Ngô',
#  'Ngô',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phùng',
#  'Quách',
#  'Tạ',
#  'Tô',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Nhang',
#  'Lê',
#  'Nguyễn',
#  'Nguyễn',
#  'Trần',
#  'Trần',
#  'Nguyễn',
#  'Vương',
#  'Vũ',
#  'Đinh',
#  'Lâm',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Võ',
#  'Vũ',
#  'Dương',
#  'Nguyễn',
#  'Hà',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Đinh',
#  'Đinh',
#  'Đoàn',
#  'Đỗ',
#  'Hoàng',
#  'Huỳnh',
#  'Lê',
#  'Nguyễn',
#  'Phạm',
#  'Tôn',
#  'Phạm',
#  'Phạm',
#  'Trương',
#  'Phạm',
#  'Trần',
#  'Dương',
#  'Đào',
#  'Đặng',
#  'Đoàn',
#  'Đỗ',
#  'Đỗ',
#  'Hoàng',
#  'Hoàng',
#  'Hồ',
#  'Khắc',
#  'La',
#  'Lâm',
#  'Lê',
#  'Lợi',
#  'Lương',
#  'Ngô',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phan',
#  'Quách',
#  'Trần',
#  'Trịnh',
#  'Trương',
#  'Từ',
#  'Võ',
#  'Vũ',
#  'Đỗ',
#  'Bùi',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Trương',
#  'Văn',
#  'Vi',
#  'Đặng',
#  'Đỗ',
#  'Đỗ',
#  'Hồ',
#  'Lý',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Nguyễn',
#  'Cao',
#  'Lanaras',
#  'Bùi',
#  'Hồ',
#  'Huỳnh',
#  'Lê',
#  'Dương',
#  'Huỳnh',
#  'Nguyễn',
#  'Trần',
#  'Huỳnh',
#  'Huỳnh',
#  'Lâm',
#  'Lâm',
#  'Lý',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Thái',
#  'Lê',
#  'Trần',
#  'Dương',
#  'Hồ',
#  'Lê',
#  'Phạm',
#  'Trần',
#  'Võ',
#  'Vũ',
#  'Phạm',
#  'Lê',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phạm',
#  'Phan',
#  'Trần',
#  'Cao',
#  'Đào',
#  'Đỗ',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Đoàn',
#  'Đỗ',
#  'Hoàng',
#  'Khưu',
#  'Lê',
#  'Lê',
#  'Lý',
#  'Mai',
#  'Mai',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phạm',
#  'Đặng',
#  'Đỗ',
#  'Huỳnh',
#  'Huỳnh',
#  'Mai',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Hoàng',
#  'Hồng',
#  'Huỳnh',
#  'Lê',
#  'Lê',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Tống',
#  'Trần',
#  'Phan',
#  'Trần',
#  'Nguyễn',
#  'Châu',
#  'Đặng',
#  'Nguyễn',
#  'Dương',
#  'Hà',
#  'Huỳnh',
#  'Lê',
#  'Lê',
#  'Lương',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phạm',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trương',
#  'Võ',
#  'Võ',
#  'Đinh',
#  'Đỗ',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Phan',
#  'Thái',
#  'Huỳnh',
#  'Lê',
#  'Ngô',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phan',
#  'Tăng',
#  'Trần',
#  'Trần',
#  'Trịnh',
#  'Vương',
#  'Dương',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Tạ',
#  'Trần',
#  'Trần',
#  'Võ',
#  'Cao',
#  'Lê',
#  'Nguyễn',
#  'Võ',
#  'Bùi',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Tô',
#  'Trần',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Trần',
#  'Lã',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Trần',
#  'Lê',
#  'Cao',
#  'Đỗ',
#  'Phạm',
#  'Phạm',
#  'Vương',
#  'Đinh',
#  'Đoàn',
#  'Hồng',
#  'Huỳnh',
#  'Lê',
#  'Nguyễn',
#  'Phạm',
#  'Phan',
#  'Trần',
#  'Đặng',
#  'Đặng',
#  'Đặng',
#  'Đỗ',
#  'Đỗ',
#  'Hoàng',
#  'Hồ',
#  'Huỳnh',
#  'Huỳnh',
#  'Lê',
#  'Mạc',
#  'Ngô',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Trương',
#  'Đào',
#  'Lê',
#  'Nguyễn',
#  'Nguyễn',
#  'Vương',
#  'Dương',
#  'Đỗ',
#  'Lưu',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Châu',
#  'Đào',
#  'Đinh',
#  'Hoàng',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Mao',
#  'Nguyễn',
#  'Nguyễn',
#  'Tạ',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Võ',
#  'Nguyễn',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Đỗ',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Trần',
#  'Lê',
#  'Dương',
#  'Jomklang',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Dương',
#  'Đặng',
#  'Lê',
#  'Nguyễn',
#  'Nguyễn',
#  'Thái',
#  'Hà',
#  'Trầm',
#  'Võ',
#  'Bùi',
#  'Dương',
#  'Đỗ',
#  'Đỗ',
#  'Hoàng',
#  'Huỳnh',
#  'Huỳnh',
#  'Huỳnh',
#  'Lê',
#  'Lê',
#  'Mai',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phan',
#  'Tiền',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trương',
#  'Võ',
#  'Võ',
#  'Võ',
#  'Võ',
#  'Vương',
#  'Bùi',
#  'Nguyễn',
#  'Huỳnh',
#  'Lê',
#  'Vũ',
#  'Dương',
#  'Nguyễn',
#  'Dương',
#  'Hoàng',
#  'Lê',
#  'Lê',
#  'Nguyễn',
#  'Phan',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Viên',
#  'Lê',
#  'Lương',
#  'Ngũ',
#  'Nguyễn',
#  'Trần',
#  'Bùi',
#  'Lê',
#  'Phan',
#  'Đỗ',
#  'Huỳnh',
#  'Ngô',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trương',
#  'Trương',
#  'Trương',
#  'Võ',
#  'Diệp',
#  'Huỳnh',
#  'Lê',
#  'Lương',
#  'Ma',
#  'Ngô',
#  'Phạm',
#  'Trần',
#  'Trần',
#  'Trịnh',
#  'Dương',
#  'Đỗ',
#  'Phạm',
#  'Phạm',
#  'Huỳnh',
#  'Nguyễn',
#  'Phùng',
#  'Trần',
#  'Trần',
#  'Lê',
#  'Trần',
#  'Huỳnh',
#  'Lê',
#  'Nguyễn',
#  'Phạm',
#  'Vương',
#  'Vương',
#  'Đào',
#  'Nguyễn',
#  'Lương',
#  'Nguyễn',
#  'Mai',
#  'Nguyễn',
#  'Nguyễn',
#  'Lương',
#  'Bạch',
#  'Huỳnh',
#  'Huỳnh',
#  'Lâm',
#  'Lê',
#  'Lê',
#  'Lương',
#  'Lưu',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phùng',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Từ',
#  'Vương',
#  'Huỳnh',
#  'Phùng',
#  'Tiêu',
#  'Châu',
#  'Huỳnh',
#  'Nguyễn',
#  'Nguyễn',
#  'Đoàn',
#  'Hoàng',
#  'Hồ',
#  'Nguyễn',
#  'Trần',
#  'Nghiêm',
#  'Ngô',
#  'Trương',
#  'Quan',
#  'Diệp',
#  'Hồ',
#  'Lương',
#  'Nguyễn',
#  'Đặng',
#  'Đoàn',
#  'Lê',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Tăng',
#  'Trần',
#  'Võ',
#  'Nguyễn',
#  'Phạm',
#  'Trần',
#  'Võ',
#  'Vũ',
#  'Ha',
#  'Soon',
#  'Bành',
#  'Bùi',
#  'Đoàn',
#  'Đỗ',
#  'Hà',
#  'Hoàng',
#  'Lâm',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Ngô',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phạm',
#  'Phan',
#  'Trác',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Võ',
#  'Võ',
#  'Châu',
#  'Châu',
#  'Huỳnh',
#  'Lâm',
#  'Lê',
#  'Lê',
#  'Lưu',
#  'Thái',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Võ',
#  'Hồ',
#  'Bùi',
#  'Dương',
#  'Huỳnh',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Lại',
#  'Nguyễn',
#  'Nguyễn',
#  'Trần',
#  'Huỳnh',
#  'Nguyễn',
#  'Đào',
#  'Đặng',
#  'Đồng',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Liu',
#  'Lý',
#  'Lý',
#  'Mai',
#  'Mai',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phạm',
#  'Phan',
#  'Tô',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trương',
#  'Trương',
#  'Võ',
#  'Đoàn',
#  'Huỳnh',
#  'Lý',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Lý',
#  'Bùi',
#  'Cao',
#  'Cao',
#  'Hà',
#  'Hồ',
#  'Huỳnh',
#  'Huỳnh',
#  'Lê',
#  'Lục',
#  'Lương',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Vũ',
#  'Vũ',
#  'Vũ',
#  'Lương',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Tô',
#  'Trần',
#  'Ngô',
#  'Lê',
#  'Mai',
#  'Nguyễn',
#  'Đoàn',
#  'Đỗ',
#  'Lê',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Võ',
#  'Nguyễn',
#  'Nguyễn',
#  'Trương',
#  'Cao',
#  'Đào',
#  'Đỗ',
#  'Đỗ',
#  'Hồ',
#  'Hồng',
#  'Huỳnh',
#  'Huỳnh',
#  'La',
#  'Lại',
#  'Lê',
#  'Lê',
#  'Lương',
#  'Ngô',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phạm',
#  'Phan',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Trần',
#  'Vân',
#  'Võ',
#  'Vũ',
#  'Lê',
#  'Lê',
#  'Phạm',
#  'Trần',
#  'Trịnh',
#  'Chung',
#  'Đào',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Lê',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Nguyễn',
#  'Phan',
#  'Phan',
#  'Trần',
#  'Nguyễn',
#  'Nguyễn',
#  'Trương',
#  'Tô',
#  'Trần',
#  'Đặng',
#  'Đinh',
#  'Đỗ',
#  ...]

# %%
name_df = pd.DataFrame(lastnames, columns=['last name'])
name_df
# Out:
#       last name
# 0          Phạm
# 1          Đặng
# 2           Lâm
# 3            Lê
# 4            Lư
# ...         ...
# 74166    Nguyễn
# 74167    Nguyễn
# 74168    Nguyễn
# 74169      Phạm
# 74170       Văn
#
# [74171 rows x 1 columns]

# %%
name_df['last name'].value_counts().sort_values(ascending=False)
# Out:
# Nguyễn    23136
# Trần       7911
# Lê         6347
# Phạm       4377
# Huỳnh      2656
#           ...
# Hương         1
# Định          1
# Thịnh         1
# Đăng          1
# Phu           1
# Name: last name, Length: 603, dtype: int64

# %%
name_df['first name'] = df['name'].apply(lambda x: x.split(" ")[-1])
name_df
# Out:
#       last name first name
# 0          Phạm         Ái
# 1          Đặng         An
# 2           Lâm         An
# 3            Lê         An
# 4            Lư         An
# ...         ...        ...
# 74166    Nguyễn        Yến
# 74167    Nguyễn        Yến
# 74168    Nguyễn        Yến
# 74169      Phạm        Yến
# 74170       Văn        Yến
#
# [74171 rows x 2 columns]

# %%
name_by_popularity = name_df['first name'].value_counts().sort_values(ascending=False)
name_by_popularity
# Out:
# Anh      2907
# Vy       1813
# Nhi      1650
# Huy      1594
# Linh     1481
#          ...
# Giảng       1
# Khắc        1
# Của         1
# Ting        1
# Bé          1
# Name: first name, Length: 993, dtype: int64

# %% [markdown]
# ### Top 20 names

# %%
name_by_popularity[0:20]
# Out:
# Anh       2907
# Vy        1813
# Nhi       1650
# Huy       1594
# Linh      1481
# Ngân      1448
# Thư       1253
# Ngọc      1155
# Như       1047
# Thảo      1045
# Minh      1036
# Đạt       1036
# Phương     998
# Trang      940
# Phúc       902
# Khoa       895
# Bảo        878
# Duy        866
# Quỳnh      773
# Hân        768
# Name: first name, dtype: int64

# %% [markdown]
# ### Longest name

# %%
name_df['full name'] = df['name']
name_df
# Out:
#       last name first name                full name
# 0          Phạm         Ái      Phạm Hoàng Hương Ái
# 1          Đặng         An       Đặng Huỳnh Vĩnh An
# 2           Lâm         An  Lâm Nguyễn Mộng Thùy An
# 3            Lê         An         Lê Tiêu Hoàng An
# 4            Lư         An              Lư Thuận An
# ...         ...        ...                      ...
# 74166    Nguyễn        Yến      Nguyễn Đình Hải Yến
# 74167    Nguyễn        Yến       Nguyễn Thị Hải Yến
# 74168    Nguyễn        Yến     Nguyễn Trần Tiểu Yến
# 74169      Phạm        Yến         Phạm Thị Kim Yến
# 74170       Văn        Yến             Văn Hồng Yến
#
# [74171 rows x 3 columns]

# %%
name_df['length'] = name_df['full name'].apply(lambda x: len(x))
name_df
# Out:
#       last name first name                full name  length
# 0          Phạm         Ái      Phạm Hoàng Hương Ái      19
# 1          Đặng         An       Đặng Huỳnh Vĩnh An      18
# 2           Lâm         An  Lâm Nguyễn Mộng Thùy An      23
# 3            Lê         An         Lê Tiêu Hoàng An      16
# 4            Lư         An              Lư Thuận An      11
# ...         ...        ...                      ...     ...
# 74166    Nguyễn        Yến      Nguyễn Đình Hải Yến      19
# 74167    Nguyễn        Yến       Nguyễn Thị Hải Yến      18
# 74168    Nguyễn        Yến     Nguyễn Trần Tiểu Yến      20
# 74169      Phạm        Yến         Phạm Thị Kim Yến      16
# 74170       Văn        Yến             Văn Hồng Yến      12
#
# [74171 rows x 4 columns]

# %%
name_df['length'].max()
# Out:
# 31

# %%
name_df.loc[name_df['length'] == name_df['length'].max()]['full name']
# Out:
# 4945     Nguyễn Xuân Quỳnh Giao - Rosafi
# 33071    Đoàn Huỳnh Nguyễn Châu Thanh Tú
# Name: full name, dtype: object

# %% [markdown]
# # Todo: Draw bar charts and add questions as markdown for the remaining tasks
